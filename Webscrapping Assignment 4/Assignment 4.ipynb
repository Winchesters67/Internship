# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import requests
import numpy as np
# !pip install urllib3

# %%
#2
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https://www.bcci.tv/")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4792\3092009176.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")

# %%
search=driver.find_element(By.XPATH,"/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button")
search.click()

# %%
series=[]
title=[]
place=[]
date=[]
time=[]

seriess=driver.find_elements(By.XPATH,"//h5[@class='fix-text']")
for i in seriess:
    series.append(i.text)
serie=series[1:40:2]

titles=driver.find_elements(By.XPATH,"//span[@class='matchOrderText ng-binding ng-scope']")
for i in titles:
    title.append(i.text[0:8])

places=driver.find_elements(By.XPATH,"//div[@class='fix-place ng-binding ng-scope']")
for i in places:
    place.append(i.text.split(' - ')[1:10:2])

dates=driver.find_elements(By.XPATH,"//h5[@class='ng-binding']")
for i in dates:
    date.append(i.text)
    

times=driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']")
for i in times:
    time.append(i.text)

# %%
df=pd.DataFrame({'Match title':title,'Series':serie,'Place':place,'Date':date,'Time':time})
df
# Out:
#   Match title                                       Series  \
# 0    1st T20I                ICC WOMENS T20 WORLD CUP 2023
# 1    2nd T20I                ICC WOMENS T20 WORLD CUP 2023
# 2    2nd Test  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 3    3rd T20I                ICC WOMENS T20 WORLD CUP 2023
# 4    4th T20I                ICC WOMENS T20 WORLD CUP 2023
# 5    3rd Test  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 6    4th Test  AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# 7    1st ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 8    2nd ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 9    3rd ODI    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                Place         Date         Time
# 0                              [Newlands, Cape Town]  12 FEB 2023  6:30 PM IST
# 1                              [Newlands, Cape Town]  15 FEB 2023  6:30 PM IST
# 2                      [Arun Jaitley Stadium, Delhi]  17 FEB 2023  9:30 AM IST
# ...

# %%
#3
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("http://statisticstimes.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
search.click()

# %%
rank=[]
state=[]
GSDP1920=[]
GSDP1819=[]
share1819=[]
GDP=[]

ranks=driver.find_elements(By.XPATH,"//td[@class='data1']")
for i in ranks:
    rank.append(i.text)
rankk=rank[0:33]

states=driver.find_elements(By.XPATH,"//td[@class='name']")
for i in states:
    state.append(i.text)
statee=state[0:33]


GSDP1920s=driver.find_elements(By.XPATH,"//td[@class='data sorting_1']")
for i in GSDP1920s:
    GSDP1920.append(i.text)
GSDP19200=GSDP1920[0:33]


GSDP1819s=driver.find_elements(By.XPATH,"//td[@class='data']")
for i in GSDP1819s:
    GSDP1819.append(i.text)
GSDP18199=GSDP1819[0:165:5]


share1819s=driver.find_elements(By.XPATH,"//td[@class='data']")
for i in share1819s:
    share1819.append(i.text)
share18199=share1819[1:165:5]


GDPs=driver.find_elements(By.XPATH,"//td[@class='data']")
for i in GDPs:
    GDP.append(i.text)
GDPP=GDP[2:165:5]

# %%
df=pd.DataFrame({'Rank':rankk,'State':statee,'GSDP(18-19)-at current prices':GSDP19200,'GSDP(19-20)-at current prices':GSDP18199,'Share(18-19)':share18199,'GDP($ billion)':GDPP})
df

# %%
#4
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https://github.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
search.click()

# %%
title=[]
desc=[]
count=[]
lang=[]


titles=driver.find_elements(By.XPATH,"//span[@class='text-normal']")
for i in titles:
    title.append(i.text.split(' /')[0])


descr=driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
for i in descr:
    desc.append(i.text)


counts=driver.find_elements(By.XPATH,"//a[@class='Link--muted d-inline-block mr-3']")
for i in counts:
    count.append(i.text)
    

try:
    langs=driver.find_elements(By.XPATH,"//span[@class='d-inline-block ml-0 mr-3']")
    for i in langs:
        lang.append(i.text)
except NoSuchElementException:
        lang.append('-')

# %%
#5
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https:/www.billboard.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")
search.click()

# %%
sname=[]
artist=[]
prevrnk=[]
prevrank=[]
peak=[]
weeks=[]

snames=driver.find_elements(By.XPATH,"//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in snames:
    sname.append(i.text)


artists=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in artists:
    artist.append(i.text)

prevrnk=[]
prevrnks=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in prevrnks:
    prevrnk.append(i.text)
prevrank=prevrnk[3::6]

peak=prevrnk[4::6]

weeks=prevrnk[5::6]

# %%
#6
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
table=[]
genre=[]
bookname=[]
author=[]
volsld=[]
publisher=[]

table=[]
tables=driver.find_elements(By.XPATH,"//td[@class='left']")
for i in tables:
    table.append(i.text)
bookname=table[1::5]
author=table[2::5]
volsld=table[3::5]
publisher=table[4::5]

genres=driver.find_elements(By.XPATH,"//td[@class='last left']")
for i in genres:
    genre.append(i.text)

# %%
#7
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https://www.imdb.com/list/ls095964455")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22468\751286366.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")

# %%
name=[]
year=[]
genre=[]
runt=[]

names=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']")
for i in names:
    name.append(i.text.split('. ')[1])

years=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
for i in years:
    year.append(i.text)
    

genres=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in genres:
    genre.append(i.text)
    

runtime=driver.find_elements(By.XPATH,"//span[@class='runtime']")
for i in runtime:
    runt.append(i.text)

# %%
#8
driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")
driver.get("https://archive.ics.uci.edu/")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22468\3048974970.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HP\Desktop\Fliprobo notes\chromedriver.exe")

# %%
search=driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td/span/b/a")
search.click()

# %%
Dataset=[]
Datasets=driver.find_elements(By.XPATH,"//p[@class='normal']")
for i in Datasets:
    Dataset.append(i.get_attribute('href'))
Dataset
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
